# %%
from model import *
from model import dice_loss
from data import *
from tensorflow import keras

# os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# initialize the model
model = keras.models.load_model('unet_larynx.hdf5', custom_objects={'dice_loss': dice_loss, 'dice_coefficient': dice_coefficient})

# %% [markdown]
# ### Load the model

# %% [markdown]
# ### Unpack video data

# %%
# unpack_video data/larynx/segment/input/alieva.mp4
unpack_video('data/larynx/segment', video_folder='input', image_folder='image_tmp', target_size=(256, 256))

# %% [markdown]
# ### Segment images from "image_tmp" directory

# %%
folder_path = 'data/larynx/segment/image_tmp'

test_dataset = test_dataset_generator(folder_path)
classes = model.predict(test_dataset, 3, verbose=1)
saveResult("data/larynx/segment/segment_tmp", classes)
# Out:
# 685/685 [==============================] - 11s 13ms/step
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\0_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\1_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\2_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\13_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\24_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\29_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\30_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\31_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\32_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\33_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\34_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\35_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\36_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\37_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\38_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\39_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\40_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\41_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\42_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\43_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\44_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\45_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\46_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\47_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\48_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\57_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\62_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\63_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\64_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\65_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\66_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\67_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\68_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\69_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\70_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\71_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\72_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\73_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\74_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\75_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\76_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\77_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\78_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\79_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\80_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\81_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\82_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\83_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\90_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\101_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\112_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\113_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\122_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\123_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\124_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\125_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\126_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\127_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\128_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\129_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\130_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\131_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\132_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\133_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\134_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\135_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\136_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\137_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\138_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\140_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\141_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\142_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\143_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\144_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\145_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\146_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\147_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\148_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\149_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\150_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\151_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\152_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\153_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\154_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\155_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\156_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\157_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\158_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\159_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\160_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\161_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\162_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\163_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\164_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\165_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\166_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\186_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# ...
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\574_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\652_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\663_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# c:\dev\git\larynx_NN_model\data.py:297: UserWarning: data/larynx/segment/segment_tmp\674_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.

# %% [markdown]
# ### Export as a video

# %%
import ffmpeg
ffmpeg.input('data/larynx/segment/segment_tmp/*.png', pattern_type='glob', framerate=30).output('data/larynx/segment/output/anosova.mp4').run()
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# c:\dev\git\larynx_NN_model\segment_video.ipynb Cell 8 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/dev/git/larynx_NN_model/segment_video.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> import ffmpeg
# ----> <a href='vscode-notebook-cell:/c%3A/dev/git/larynx_NN_model/segment_video.ipynb#X11sZmlsZQ%3D%3D?line=1'>2</a> ffmpeg.input('data/larynx/segment/segment_tmp/*.png', pattern_type='glob', framerate=30).output('data/larynx/segment/output/anosova.mp4').run()
#
# File c:\Users\perseusf\anaconda3\lib\site-packages\ffmpeg\_run.py:325, in run(stream_spec, cmd, capture_stdout, capture_stderr, input, quiet, overwrite_output)
#     323 retcode = process.poll()
#     324 if retcode:
# --> 325     raise Error('ffmpeg', out, err)
#     326 return out, err
#
# Error: ffmpeg error (see stderr output for detail)
