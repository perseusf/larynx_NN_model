# %%
from model import *
from data import *
from tensorflow import keras
import keras.utils as image

# initialize the model
model = keras.models.load_model('unet_larynx.hdf5')

# unpack_video data/larynx/segment/input/alieva.mp4
unpack_video('data/larynx/segment', video_folder='input', image_folder='image_tmp', target_size=(256, 256))
# Out:
# OpenCV: Couldn't read video stream from file "data/larynx/segment/input/.DS_Store"
# [ERROR:0@517.227] global cap.cpp:166 open VIDEOIO(CV_IMAGES): raised OpenCV exception:
#
# OpenCV(4.7.0) /Users/runner/work/opencv-python/opencv-python/opencv/modules/videoio/src/cap_images.cpp:253: error: (-5:Bad argument) CAP_IMAGES: can't find starting number (in the name of file): data/larynx/segment/input/.DS_Store in function 'icvExtractPattern'

# %%
# load all images into a list
images = []
folder_path = 'data/larynx/segment/image_tmp'
target_size=(256, 256)

for img in os.listdir(folder_path):
    img = os.path.join(folder_path, img)
    img = image.load_img(img, target_size)
    img = image.img_to_array(img)
    img = np.expand_dims(img, axis=0)
    images.append(img)

# stack up images list to pass for prediction
images = np.vstack(images)
classes = model.predict(images, batch_size=5)
# Out:
# /Users/bzavolovich/anaconda3/lib/python3.10/site-packages/keras/utils/image_utils.py:409: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn(
#   4/246 [..............................] - ETA: 11:04
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 15
#      13 # stack up images list to pass for prediction
#      14 images = np.vstack(images)
# ---> 15 classes = model.predict(images, batch_size=5)
#
# File ~/anaconda3/lib/python3.10/site-packages/keras/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ...

# %%
saveResult("data/larynx/segment/segment_tmp", classes)
# Out:
# /Users/bzavolovich/Developer/larynx_NN_model/data.py:308: UserWarning: data/larynx/segment/segment_tmp/0_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /Users/bzavolovich/Developer/larynx_NN_model/data.py:308: UserWarning: data/larynx/segment/segment_tmp/1_predict.png is a low contrast image
#   io.imsave(os.path.join(save_path, "%d_predict.png" % i), img)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /Users/bzavolovich/Developer/larynx_NN_model/data.py:308: UserWarning: data/larynx/segment/segment_tmp/3_predict.png is a low contrast image
# ...

# %%
import os
import ffmpeg

def create_video(input_folder, output_file, fps=24):
    # Get all PNG files in the input folder
    input_files = [f for f in os.listdir(input_folder) if f.endswith('.png')]

    # Generate the input file list for FFmpeg
    input_files_paths = [os.path.join(input_folder, file) for file in input_files]

    # Create FFmpeg input stream
    input_stream = ffmpeg.concat(*input_files_paths, v=1, a=0)

    # Set video codec and pixel format
    output_stream = ffmpeg.output(input_stream, output_file, vcodec='libx264', pix_fmt='yuv420p', r=fps)

    # Execute FFmpeg process
    ffmpeg.run(output_stream, overwrite_output=True)
    print("Video successfully created.")

    # Execute FFmpeg process
    ffmpeg.run(output_stream, overwrite_output=True)
    print("Video successfully created.")

# Usage example
input_folder = 'data/larynx/segment/segment_tmp'
output_file = 'data/larynx/segment/output/segment_strobo.mp4'
fps = 30

create_video(input_folder, output_file, fps)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 30
#      27 output_file = 'data/larynx/segment/output/segment_strobo.mp4'
#      28 fps = 30
# ---> 30 create_video(input_folder, output_file, fps)
#
# Cell In[7], line 12, in create_video(input_folder, output_file, fps)
#       9 input_files_paths = [os.path.join(input_folder, file) for file in input_files]
#      11 # Create FFmpeg input stream
# ---> 12 input_stream = ffmpeg.concat(*input_files_paths, v=1, a=0)
#      14 # Set video codec and pixel format
#      15 output_stream = ffmpeg.output(input_stream, output_file, vcodec='libx264', pix_fmt='yuv420p', r=fps)
#
# File ~/anaconda3/lib/python3.10/site-packages/ffmpeg/_filters.py:399, in concat(*streams, **kwargs)
#     393     raise ValueError(
#     394         'Expected concat input streams to have length multiple of {} (v={}, a={}); got {}'.format(
# ...

# %%
ffmpeg.input('data/larynx/segment/segment_tmp/*.png', pattern_type='glob', framerate=30).output('data/larynx/segment/output/segment_strobo.mp4').run()
# Out:
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 14.0.3 (clang-1403.0.22.14.1)
# ...
